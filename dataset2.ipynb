# %%
import pandas as pd
data=pd.DataFrame({
    "name":['anu','ammu','anu','binnu'],
    "age":[18,17,18,79]}) 
print(data.duplicated())
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
import pandas as pd
dataset={
    "Name":["noah","jonas","martha","luke"],
     "Age":[43,45,67,33]
}
result=pd.DataFrame(dataset)
print(result)
# Out:
#      Name  Age
# 0    noah   43
# 1   jonas   45
# 2  martha   67
# 3    luke   33

# %%
import pandas as pd
dataset={
    "Name":["noah","jonas","martha","luke"],
     "Age":[43,45,67,33]
}
result=pd.DataFrame(dataset)
print(result.duplicated())
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool

# %%
import pandas as pd
dataset={
    "Name":["noah","jonas","martha","noah"],
     "Age":[43,45,67,43]
}
result=pd.DataFrame(dataset)
print(result.drop_duplicates())
# Out:
#      Name  Age
# 0    noah   43
# 1   jonas   45
# 2  martha   67

# %%
employee={
    "Name":["ashmitha","akshaya","dhruvitha","ananya","mokshitha"],
    "salary":[34000,78000,67000,72000,64000]
}
result=pd.DataFrame(employee)
print(result)
# Out:
#         Name  salary
# 0   ashmitha   34000
# 1    akshaya   78000
# 2  dhruvitha   67000
# 3     ananya   72000
# 4  mokshitha   64000

# %%
employee={
    "Name":["ashmitha","akshaya","dhruvitha","ananya","mokshitha"],
    "salary":[34000,78000,67000,72000,64000]
}
result=pd.DataFrame(employee)
print(result[result["salary"]>50000])
# Out:
#         Name  salary
# 1    akshaya   78000
# 2  dhruvitha   67000
# 3     ananya   72000
# 4  mokshitha   64000

# %%
print(result.query("salary>30000"))
# Out:
#         Name  salary
# 0   ashmitha   34000
# 1    akshaya   78000
# 2  dhruvitha   67000
# 3     ananya   72000
# 4  mokshitha   64000

# %%
print(result.query("salary>30000 and salary<50000"))
# Out:
#        Name  salary
# 0  ashmitha   34000

# %%
favfruits={
    "fruits":["mango","jamun","strawberry","litchi"]
}
result=pd.DataFrame(favfruits)
print(result)
# Out:
#        fruits
# 0       mango
# 1       jamun
# 2  strawberry
# 3      litchi

# %%
(result.sample())
# Out:
#   fruits
# 1  jamun

# %%
(result.sample(3))
# Out:
#    fruits
# 3  litchi
# 0   mango
# 1   jamun

# %%
(result.sample(3,random_state=0))
# Out:
#        fruits
# 2  strawberry
# 3      litchi
# 1       jamun
