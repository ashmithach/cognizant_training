# %%
import pandas as pd
data={
    "Date":["14-05-2007","04-04-1988","06-06-1982"]
}

result=pd.DataFrame(data)
print(result)
# Out:
#          Date
# 0  14-05-2007
# 1  04-04-1988
# 2  06-06-1982

# %%
result["Date"]=pd.to_datetime(result["Date"])
print(result)
# Out:
#         Date
# 0 2007-05-14
# 1 1988-04-04
# 2 1982-06-06

# %%
result["Date"]=pd.to_datetime(result["Date"])
result["Date"].dt.year
print(result)
# Out:
#         Date
# 0 2007-05-14
# 1 1988-04-04
# 2 1982-06-06

# %%
result["Date"].dt.year
# Out:
# 0    2007
# 1    1988
# 2    1982
# Name: Date, dtype: int32

# %%
result["Date"].dt.month
# Out:
# 0    5
# 1    4
# 2    6
# Name: Date, dtype: int32

# %%
result["Date"].dt.day
# Out:
# 0    14
# 1     4
# 2     6
# Name: Date, dtype: int32

# %%
result["Date"].dt.time
# Out:
# 0    00:00:00
# 1    00:00:00
# 2    00:00:00
# Name: Date, dtype: object

# %%
result["Date"].dt.day_name()
# Out:
# 0    Monday
# 1    Monday
# 2    Sunday
# Name: Date, dtype: object

# %%
pd.Timestamp.now()
# Out:
# Timestamp('2026-06-18 16:22:23.428208')

# %%
import pandas as pd
from datetime import datetime
date1=datetime(2007,5,14)
date2=datetime(2005,12,25)
print(date2-date1)
# Out:
# -505 days, 0:00:00
