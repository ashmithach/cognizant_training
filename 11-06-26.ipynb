# %%
print("hello")
# Out:
# hello

# %%
s="ashmitha"
p="123"
K="abc"

# %%
name="ashmitha"
print(name)
# Out:
# ashmitha

# %%
name="ashmitha"
email="ashmithachettipelly@gmail.com"
print(name)
print(email)
# Out:
# ashmitha
# ashmithachettipelly@gmail.com

# %%
city="newyork"
print(city[4])
# Out:
# o

# %%
city="newyork"
print(city[-4])
# Out:
# y

# %%
name="supercalifragilisticexpialidocious"
print(name[-7])
# Out:
# d

# %%
name="supercalifragilisticexpialidocious"
print(name[1:8])
# Out:
# upercal

# %%
name="supercalifragilisticexpialidocious"
print(name[1:12])
# Out:
# upercalifra

# %%
name="supercalifragilisticexpialidocious"
print(len(name))
# Out:
# 34

# %%
name1="supercalifragilistic"
name2="expialidocious"
print(name1+name2)
# Out:
# supercalifragilisticexpialidocious

# %%
s="hello"
print("hello"*3)
# Out:
# hellohellohello

# %%
s="hello"
print("hello"*15)
# Out:
# hellohellohellohellohellohellohellohellohellohellohellohellohellohellohello

# %%
s="hi"
print("hi"*100)
# Out:
# hihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihihi

# %%
s="ASHMITHA"
print("ASHMITHA")
# Out:
# ASHMITHA

# %%
s="ASHMITHA"
print("ASHMITHA"*5)
# Out:
# ASHMITHAASHMITHAASHMITHAASHMITHAASHMITHA

# %%
s="ashmitha"
print(s.upper())
# Out:
# ASHMITHA

# %%
s="ashmitha chettipelly"
print(s.lower())
# Out:
# ashmitha chettipelly

# %%
s="ASHMITHA CHETTIPELLY"
print(s.lower())
# Out:
# ashmitha chettipelly

# %%
s="i like icecream"
print(s.replace("icecream","chocolate"))
# Out:
# i like chocolate

# %%
s="anything something"
print(s.find("something"))
# Out:
# 9

# %%
name=input("Enter the name:")
print("welcome",name)
