# %%
try:
     file = open("xyz.txt", "r")
except FileNotFoundError:
     print("file does not exist")
# Out:
# file does not exist

# %%
try:
    age=int(input("enter the age:"))

except ValueError:
    print("enter number only")
# Out:
# enter the age: ashmitha
# enter number only

# %%
try:
    age=int(input("enter the age:"))

except ValueError:
    print("enter number only")
# Out:
# enter the age: 19

# %%
try:
    flower=int(input("enter the flower"))

except ValueError:
    print("enter flower only")
# Out:
# enter the flower zebra
# enter flower only

# %%
try:
    flower=int(input("enter the flower"))

except ValueError:
    print("enter flower only")
# Out:
# enter the flower rose
# enter flower only
