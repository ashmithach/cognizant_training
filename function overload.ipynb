# %%
name="ashmitha"
def greet():
    print("hello",name)
greet()
# Out:
# hello ashmitha

# %%
def add(a,b):
  return a+b
print(add(100,50))
# Out:
# 150

# %%
def add(a,b,c=0):
    return a+b+c
print(add(10,20))
print(add(10,20,30))
# Out:
# 30
# 60

# %%
def multiply(a,b,c=2):
    return a*b*c
print(multiply(10,20))
# Out:
# 400

# %%
def add(*numbers):
    print(sum(numbers))
add(10,20)
add(10,20,30)
add(10,20,30,40)
add(10,20,30,40,50)
# Out:
# 30
# 60
# 100
# 150

# %%
def student(*marks):
    print(sum(marks))
student(23,56)
student(423,343)
student(45,87)
# Out:
# 79
# 766
# 132
