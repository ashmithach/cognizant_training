# %%
import random
toss=random.choice(["Head","Tail"])
print(toss)
# Out:
# Head

# %%
import random
toss=random.choice(["Head","Tail"])
print(toss)
# Out:
# Tail

# %%
heads=0
tails=0
for i in range(1,100):
    toss=random.choice(["Head","Tail"])

    if toss=="head":
        heads+=1
    else:
        tails+=1
print("Head:",heads)
print("Tail:",tails)
# Out:
# Head: 0
# Tail: 99

# %%
import numpy as np
arr=np.array([1,2,3,4,5,6])
