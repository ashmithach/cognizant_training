# %%
import pandas as pd
s=pd.Series([10,20,30,40,50])
print(s.sum())
print(s.min())
print(s.max())
print(s.mean())
# Out:
# 150
# 10
# 50
# 30.0

# %%
s=pd.Series([40,56,67,89,23])
print(s[s>40])
# Out:
# 1    56
# 2    67
# 3    89
# dtype: int64

# %%
b=pd.Series([43,34,56,65,67,76])
print([b>49])
# Out:
# [0    False
# 1    False
# 2     True
# 3     True
# 4     True
# 5     True
# dtype: bool]

# %%
import numpy as np
import pandas as pd
s=pd.Series([34,56,np.nan,17,33])
print(s)
# Out:
# 0    34.0
# 1    56.0
# 2     NaN
# 3    17.0
# 4    33.0
# dtype: float64

# %%
import numpy as np
import pandas as pd
s=pd.Series([34,56,np.nan,17,33])
print(s)
print(s.isnull())
print(s.isnull().sum())
# Out:
# 0    34.0
# 1    56.0
# 2     NaN
# 3    17.0
# 4    33.0
# dtype: float64
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool
# 1

# %%
import numpy as np
import pandas as pd
s=pd.Series([34,56,np.nan,17,33])
print(s)
print(s.isnull())
print(s.isnull().sum())
print(s.fillna(0))
# Out:
# 0    34.0
# 1    56.0
# 2     NaN
# 3    17.0
# 4    33.0
# dtype: float64
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool
# 1
# 0    34.0
# 1    56.0
# 2     0.0
# 3    17.0
# 4    33.0
# dtype: float64

# %%
names=pd.Series(["mary jane","zendaya","sadie","peter","donna","rue"])
print(names)
# Out:
# 0    mary jane
# 1      zendaya
# 2        sadie
# 3        peter
# 4        donna
# 5          rue
# dtype: object

# %%
names=pd.Series(["mary jane","zendaya","sadie","peter","donna","rue"])
print(names.str.upper())
# Out:
# 0    MARY JANE
# 1      ZENDAYA
# 2        SADIE
# 3        PETER
# 4        DONNA
# 5          RUE
# dtype: object

# %%
n=pd.Series([34,54,435,133,125,643])
print(s.sort_values())
# Out:
# 3    17.0
# 4    33.0
# 0    34.0
# 1    56.0
# 2     NaN
# dtype: float64

# %%
s=pd.Series([34,54,435,133,125,643])
print(s.sort_values())
print(s.sort_values(ascending=False))
# Out:
# 0     34
# 1     54
# 4    125
# 3    133
# 2    435
# 5    643
# dtype: int64
# 5    643
# 2    435
# 3    133
# 4    125
# 1     54
# 0     34
# dtype: int64

# %%
n=pd.Series([133,54,435,133,133,643])
print(n.unique())
# Out:
# [133  54 435 643]

# %%
s=pd.Series([432,56,432,423,432,656567])
print(s.value_counts())
# Out:
# 432       3
# 56        1
# 423       1
# 656567    1
# Name: count, dtype: int64

# %%
s=pd.Series([432,56,432,423,432,656567])
print(s.tolist())
# Out:
# [432, 56, 432, 423, 432, 656567]

# %%
import pandas as pd
import numpy as np
s=pd.Series([34,56,np.nan,17,33])
print(s.dropna())
# Out:
# 0    34.0
# 1    56.0
# 3    17.0
# 4    33.0
# dtype: float64

# %%
b=pd.Series([124,144,346,572,452])
print(b[b>40]&b[b<153])
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# dtype: bool
# C:\Users\Ashmitha\AppData\Local\Temp\ipykernel_22160\525953751.py:2: FutureWarning: Operation between Series with different indexes that are not of numpy boolean or object dtype will no longer return a numpy boolean result in a future version. Cast both Series to object type to maintain the prior behavior.
#   print(b[b>40]&b[b<153])
