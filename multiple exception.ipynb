# %%
try:
    num=int(input("enter the number"))
    print(10/num)
except ZeroDivisionError:
    print("divide only with zero")
except ValueError:
    print("enter digits only")
# Out:
# enter the number 57
# 0.17543859649122806

# %%
try:
    num=int(input("enter the number"))
    print(10/num)
except ZeroDivisionError:
    print("divide only with zero")
except ValueError:
    print("enter digits only")
# Out:
# enter the number 78
# 0.1282051282051282

# %%
try:
    num=float(input("enter the number"))
    print(10/num)
except ZeroDivisionError:
    print("divide only with zero")
except ValueError:
    print("enter digits only")
# Out:
# enter the number 7.4543
# 1.3415075862254002

# %%
try:
    num=float(input("enter the number"))
    print(10/num)
except ZeroDivisionError:
    print("divide only with zero")
except ValueError:
    print("enter digits only")
# Out:
# enter the number 5.76
# 1.7361111111111112
