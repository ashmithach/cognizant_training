# %%
class Car()
    colour="Red"
    brand="BMW"
    speed=120

    car1=Car()
    print(car1.colour)
    print(car1.brand)
# Out:
#   Cell In[17], line 1
#     class Car()
#                ^
# SyntaxError: expected ':'

# %%
class Car:
    colour="Red"
    brand="BMW"
    speed=120

    car1=Car
    print(car1.colour)
    print(car1.brand)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 class Car:
#       2     colour="Red"
#       3     brand="BMW"
#
# Cell In[16], line 6, in Car()
#       3 brand="BMW"
#       4 speed=120
# ----> 6 car1=Car
#       7 print(car1.colour)
#       8 print(car1.brand)
#
# NameError: name 'Car' is not defined

# %%
class Car:
    colour ="Red"
    brand ="BMW"
    speed =120

    car1=Car
    print(car1.colour)
    print(car1.brand)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 class Car:
#       2     colour ="Red"
#       3     brand ="BMW"
#
# Cell In[18], line 6, in Car()
#       3 brand ="BMW"
#       4 speed =120
# ----> 6 car1=Car
#       7 print(car1.colour)
#       8 print(car1.brand)
#
# NameError: name 'Car' is not defined

# %%
class Car:
    colour="Red"
    brand="BMW"
    speed=120

    car1=Car
    print(car1.colour)
    print(car1.brand)
    print(Car1.speed)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 class Car:
#       2     colour="Red"
#       3     brand="BMW"
#
# Cell In[19], line 6, in Car()
#       3 brand="BMW"
#       4 speed=120
# ----> 6 car1=Car
#       7 print(car1.colour)
#       8 print(car1.brand)
#
# NameError: name 'Car' is not defined

# %%
class Bike:
    colour="Red"
    brand="BMW"
    speed=120

    Bike1=Bike
    print(car1.colour)
    print(car1.brand)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 class Bike:
#       2     colour="Red"
#       3     brand="BMW"
#
# Cell In[20], line 6, in Bike()
#       3 brand="BMW"
#       4 speed=120
# ----> 6 Bike1=Bike
#       7 print(car1.colour)
#       8 print(car1.brand)
#
# NameError: name 'Bike' is not defined

# %%
class Car:
    colour="Black"
    brand="BMW"
    speed=120

    car1=Car
    print(car1.colour)
    print(car1.brand)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 class Car:
#       2     colour="Black"
#       3     brand="BMW"
#
# Cell In[21], line 6, in Car()
#       3 brand="BMW"
#       4 speed=120
# ----> 6 car1=Car
#       7 print(car1.colour)
#       8 print(car1.brand)
#
# NameError: name 'Car' is not defined

# %%
class Car:
    colour="Red"
    brand="BMW"
    speed=120

    car1=Car
    print(car1.colour)
    print(car1.brand)
