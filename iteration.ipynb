# %%
name=["1","2","3","4","5"]
it=iter(name)
print(next(it))
print(next(it))
print(next(it))
print(next(it))
print(next(it))
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
name=["jupiter","mars","venus","earth"]
it=iter(name)
print(next(it))
print(next(it))
print(next(it))
print(next(it))
# Out:
# jupiter
# mars
# venus
# earth

# %%
name=[1,2,3,4,5]
it=iter(name)
print(next(it))
print(next(it))
print(next(it))
print(next(it))
print(next(it))
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
def numbers():
    yield 1
    yield 2
    yield 3
gen = numbers()
print(next(gen))
print(next(gen))
print(next(gen))
# Out:
# 1
# 2
# 3

# %%
file = open("demo.txt", "r")
content=file.read()
print(content)
file.close()
